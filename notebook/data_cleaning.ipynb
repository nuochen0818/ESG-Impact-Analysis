# %%
import pandas as pd
import numpy as np
import re

# %%
esg = pd.read_csv('SP 500 ESG Risk Ratings.csv')
gdp = pd.read_excel('gdp_raw.xlsx')
state_name = pd.read_excel('state_name_raw.xlsx')
fin = pd.read_excel('fin_raw.xlsx')

# %% [markdown]
# # 1. Data Cleaning for ESG dataset

# %%
# have a basic understanding of the whole dataset
esg.describe()
# Out:
#        Total ESG Risk score  Environment Risk Score  Governance Risk Score  \
# count            433.000000              433.000000             433.000000
# mean              21.422633                5.678984               6.673903
# std                7.264458                5.339965               2.201049
# min                7.000000                0.000000               3.000000
# 25%               16.000000                1.500000               5.000000
# 50%               21.000000                3.800000               6.000000
# 75%               26.000000                8.900000               7.700000
# max               46.000000               25.000000              15.500000
#
#        Social Risk Score  Controversy Score
# count         433.000000         433.000000
# mean            9.045035           1.896074
# std             3.813788           0.940748
# min             1.100000           0.000000
# 25%             6.600000           1.000000
# 50%             8.700000           2.000000
# 75%            11.600000           2.000000
# max            21.000000           5.000000

# %%
# check the data type
esg.dtypes
# Out:
# Symbol                     object
# Name                       object
# Address                    object
# Sector                     object
# Industry                   object
# Full Time Employees        object
# Description                object
# Total ESG Risk score      float64
# Environment Risk Score    float64
# Governance Risk Score     float64
# Social Risk Score         float64
# Controversy Level          object
# Controversy Score         float64
# ESG Risk Percentile        object
# ESG Risk Level             object
# dtype: object

# %%
# change the type of "Full Time Employees" from object to int
esg['Full Time Employees'] = esg['Full Time Employees'].apply(lambda x: x.replace(',', '').strip() if pd.notnull(x) else '0')
esg['Full Time Employees'] = esg['Full Time Employees'].astype(int)

# %%
# check if esg_data has null value
null_counts = esg.isnull().sum()
null_counts
# Out:
# Symbol                      0
# Name                        0
# Address                     2
# Sector                      2
# Industry                    2
# Full Time Employees         0
# Description                 2
# Total ESG Risk score       70
# Environment Risk Score     70
# Governance Risk Score      70
# Social Risk Score          70
# Controversy Level          99
# Controversy Score          70
# ESG Risk Percentile        70
# ESG Risk Level            127
# dtype: int64

# %%
# test 1: the relationship between "missing Total ESG Risk score" and "missing detailed ESG risk scores"
null_indexes_1 = esg[esg['Total ESG Risk score'].isnull() & 
                     esg['Environment Risk Score'].isnull() & 
                     esg['Governance Risk Score'].isnull()].index

# %%
# conclusion: if the company doesn't have Total ESG Risk score, the other 3 scores will be empty
# should delete 70 record later
esg.iloc[null_indexes_1]
# Out:
#     Symbol                          Name  \
# 23    ALGN          Align Technology Inc
# 24     ALK          Alaska Air Group Inc
# 28    AMCR                     Amcor Plc
# 29     AMD        Advanced Micro Devices
# 37     AON               Aon Plc Class A
# ..     ...                           ...
# 480    WBD     Warner Bros Discovery Inc
# 490    WRK                   Westrock Co
# 491    WST  West Pharmaceutical Services
# 500   ZBRA  Zebra Technologies Corp Cl A
# 501   ZION              Zions Bancorp Na
#
#                                                Address  \
# 23   410 North Scottsdale Road\nSuite 1300\nTempe, ...
# 24   19300 International Boulevard\nSeattle, WA 981...
# 28   Thurgauerstrasse 34\nZurich 8050\nSwitzerland\...
# 29   2485 Augustine Drive\nSanta Clara, CA 95054\nU...
# 37   Metropolitan Building\nJames Joyce Street\nDub...
# ..                                                 ...
# 480  230 Park Avenue South\nNew York, NY 10003\nUni...
# 490  1000 Abernathy Road NE\nAtlanta, GA 30328\nUni...
# 491  530 Herman O. West Drive\nExton, PA 19341-0645...
# 500  3 Overlook Point\nLincolnshire, IL 60069\nUnit...
# 501  One South Main Street\nSalt Lake City, UT 8413...
#
#                      Sector                        Industry  \
# 23               Healthcare                 Medical Devices
# 24              Industrials                        Airlines
# 28        Consumer Cyclical          Packaging & Containers
# 29               Technology                  Semiconductors
# 37       Financial Services               Insurance Brokers
# ..                      ...                             ...
# 480  Communication Services                   Entertainment
# 490       Consumer Cyclical          Packaging & Containers
# 491              Healthcare  Medical Instruments & Supplies
# 500              Technology         Communication Equipment
# 501      Financial Services                  Banks—Regional
#
#      Full Time Employees                                        Description  \
# 23                 22910  Align Technology, Inc. designs, manufactures, ...
# 24                 23140  Alaska Air Group, Inc., through its subsidiari...
# 28                 41000  Amcor plc develops, produces, and sells packag...
# 29                 25000  Advanced Micro Devices, Inc. operates as a sem...
# 37                 50000  Aon plc, a professional services firm, provide...
# ..                   ...                                                ...
# 480                37500  Warner Bros. Discovery, Inc., operates a media...
# 490                50500  WestRock Company, together with its subsidiari...
# 491                10700  West Pharmaceutical Services, Inc. designs, ma...
# 500                10500  Zebra Technologies Corporation, together with ...
# 501                10103  Zions Bancorporation, National Association pro...
#
#      Total ESG Risk score  Environment Risk Score  Governance Risk Score  \
# 23                    NaN                     NaN                    NaN
# 24                    NaN                     NaN                    NaN
# 28                    NaN                     NaN                    NaN
# 29                    NaN                     NaN                    NaN
# 37                    NaN                     NaN                    NaN
# ..                    ...                     ...                    ...
# 480                   NaN                     NaN                    NaN
# 490                   NaN                     NaN                    NaN
# 491                   NaN                     NaN                    NaN
# 500                   NaN                     NaN                    NaN
# 501                   NaN                     NaN                    NaN
#
#      Social Risk Score Controversy Level  Controversy Score  \
# 23                 NaN               NaN                NaN
# 24                 NaN               NaN                NaN
# 28                 NaN               NaN                NaN
# 29                 NaN               NaN                NaN
# 37                 NaN               NaN                NaN
# ..                 ...               ...                ...
# 480                NaN               NaN                NaN
# 490                NaN               NaN                NaN
# 491                NaN               NaN                NaN
# 500                NaN               NaN                NaN
# 501                NaN               NaN                NaN
#
#     ESG Risk Percentile ESG Risk Level
# 23                  NaN            NaN
# 24                  NaN            NaN
# 28                  NaN            NaN
# 29                  NaN            NaN
# 37                  NaN            NaN
# ..                  ...            ...
# 480                 NaN            NaN
# 490                 NaN            NaN
# 491                 NaN            NaN
# 500                 NaN            NaN
# 501                 NaN            NaN
#
# [70 rows x 15 columns]

# %%
# test 2: the relationship between "missing Total ESG Risk score" and "missing location, industry information"
null_indexes_2 = esg[esg['Address'].isnull() & 
                     esg['Sector'].isnull() & 
                     esg['Industry'].isnull()].index

# %%
# conclusion: only 1 company with ESG score but without company's location info
# delete 1 record
esg.iloc[null_indexes_2]
# Out:
#    Symbol                       Name Address Sector Industry  \
# 61   BF.B  Brown Forman Corp Class B     NaN    NaN      NaN
# 80    CAT            Caterpillar Inc     NaN    NaN      NaN
#
#     Full Time Employees Description  Total ESG Risk score  \
# 61                    0         NaN                   NaN
# 80                    0         NaN                  34.0
#
#     Environment Risk Score  Governance Risk Score  Social Risk Score  \
# 61                     NaN                    NaN                NaN
# 80                     7.2                    8.5               18.5
#
#    Controversy Level  Controversy Score ESG Risk Percentile ESG Risk Level
# 61               NaN                NaN                 NaN            NaN
# 80              High                4.0     76th percentile           High

# %%
# drop the records based on the conclusions above
null_indexes_combined = esg[
    (
        (esg['Total ESG Risk score'].isnull() &
        esg['Environment Risk Score'].isnull() &
        esg['Governance Risk Score'].isnull() &
        esg['Social Risk Score'].isnull())
    ) |
    (
        (esg['Address'].isnull() &
        esg['Sector'].isnull() &
        esg['Industry'].isnull())
    )
].index

esg.drop(null_indexes_combined, inplace=True)
esg.reset_index(drop=True, inplace=True)

# %%
# calculate the null values again to see if we have dropped all records we want
# won't analyze the other cols so leave the null values there
esg.isnull().sum()
# Out:
# Symbol                     0
# Name                       0
# Address                    0
# Sector                     0
# Industry                   0
# Full Time Employees        0
# Description                0
# Total ESG Risk score       0
# Environment Risk Score     0
# Governance Risk Score      0
# Social Risk Score          0
# Controversy Level         29
# Controversy Score          0
# ESG Risk Percentile        0
# ESG Risk Level            57
# dtype: int64

# %%
# no repeated value in the dataset
len(esg['Name']) == len(esg['Name'].unique())
# Out:
# True

# %%
esg
# Out:
#     Symbol                         Name  \
# 0        A     Agilent Technologies Inc
# 1      AAL  American Airlines Group Inc
# 2      AAP       Advance Auto Parts Inc
# 3     AAPL                    Apple Inc
# 4     ABBV                   Abbvie Inc
# ..     ...                          ...
# 427   XRAY          Dentsply Sirona Inc
# 428    XYL                    Xylem Inc
# 429    YUM               Yum Brands Inc
# 430    ZBH   Zimmer Biomet Holdings Inc
# 431    ZTS                   Zoetis Inc
#
#                                                Address             Sector  \
# 0    5301 Stevens Creek Boulevard\nSanta Clara, CA ...         Healthcare
# 1    1 Skyview Drive\nFort Worth, TX 76155\nUnited ...        Industrials
# 2    4200 Six Forks Road\nRaleigh, NC 27609\nUnited...  Consumer Cyclical
# 3    One Apple Park Way\nCupertino, CA 95014\nUnite...         Technology
# 4    1 North Waukegan Road\nNorth Chicago, IL 60064...         Healthcare
# ..                                                 ...                ...
# 427  13320 Ballantyne Corporate Place\nCharlotte, N...         Healthcare
# 428  300 Water Street SE\nWashington, DC 20003\nUni...        Industrials
# 429  1441 Gardiner Lane\nLouisville, KY 40213\nUnit...  Consumer Cyclical
# 430  345 East Main Street\nWarsaw, IN 46580\nUnited...         Healthcare
# 431  10 Sylvan Way\nParsippany, NJ 07054\nUnited St...         Healthcare
#
#                                    Industry  Full Time Employees  \
# 0                    Diagnostics & Research                18000
# 1                                  Airlines               132500
# 2                          Specialty Retail                40000
# 3                      Consumer Electronics               164000
# 4                Drug Manufacturers—General                50000
# ..                                      ...                  ...
# 427          Medical Instruments & Supplies                15000
# 428          Specialty Industrial Machinery                22000
# 429                             Restaurants                36000
# 430                         Medical Devices                18000
# 431  Drug Manufacturers—Specialty & Generic                13800
#
#                                            Description  Total ESG Risk score  \
# 0    Agilent Technologies, Inc. provides applicatio...                  15.0
# 1    American Airlines Group Inc., through its subs...                  29.0
# 2    Advance Auto Parts, Inc. provides automotive r...                  12.0
# 3    Apple Inc. designs, manufactures, and markets ...                  17.0
# 4    AbbVie Inc. discovers, develops, manufactures,...                  28.0
# ..                                                 ...                   ...
# 427  DENTSPLY SIRONA Inc. manufactures and sells va...                  16.0
# 428  Xylem Inc., together with its subsidiaries, en...                  16.0
# 429  Yum! Brands, Inc., together with its subsidiar...                  21.0
# 430  Zimmer Biomet Holdings, Inc., together with it...                  27.0
# 431  Zoetis Inc. discovers, develops, manufactures,...                  18.0
#
#      Environment Risk Score  Governance Risk Score  Social Risk Score  \
# 0                       0.3                    6.3                8.6
# 1                      12.0                    5.0               12.0
# 2                       0.0                    3.0                8.0
# 3                       0.6                    9.2                6.9
# 4                       1.1                    9.9               16.8
# ..                      ...                    ...                ...
# 427                     2.0                    7.0                7.0
# 428                     4.0                    5.0                7.0
# 429                     4.5                    4.4               11.6
# 430                     4.0                    8.0               15.0
# 431                     1.4                    8.9                8.1
#
#     Controversy Level  Controversy Score ESG Risk Percentile ESG Risk Level
# 0                 Low                1.0     11th percentile            Low
# 1            Moderate                2.0     62nd percentile            NaN
# 2            Moderate                2.0      4th percentile     Negligible
# 3         Significant                3.0     15th percentile            Low
# 4         Significant                3.0     55th percentile         Medium
# ..                ...                ...                 ...            ...
# 427               Low                1.0     12th percentile     Negligible
# 428               Low                1.0     13th percentile     Negligible
# 429          Moderate                2.0     27th percentile         Medium
# 430          Moderate                2.0     54th percentile            NaN
# 431               Low                1.0     20th percentile            Low
#
# [432 rows x 15 columns]

# %%
# already stored under "processed" folder
#esg.to_excel('data/processed/esg_clean.xlsx', index=False)

# %% [markdown]
# # 2. Data Cleaning for GDP dataset

# %%
gdp
# Out:
#                     state    gdp_2022    gdp_2023
# 0                    2022        2023        2022
# 1                     NaN         NaN         NaN
# 2            California *   3,598,103   3,755,487
# 3                 Texas *   2,355,960   2,436,346
# 4              New York *   2,053,180   2,135,672
# 5               Florida *   1,389,070   1,468,015
# 6              Illinois *   1,033,310   1,071,552
# 7          Pennsylvania *     923,089     961,946
# 8                  Ohio *     822,670     852,903
# 9               Georgia *     755,698     792,151
# 10           New Jersey *     745,422     776,923
# 11       North Carolina *     730,072     762,866
# 12           Washington *     725,514     761,415
# 13        Massachusetts *     688,392     721,876
# 14             Virginia *     649,393     676,734
# 15             Michigan *     620,696     645,293
# 16             Colorado *     484,372     502,026
# 17            Tennessee *     475,755     502,664
# 18             Maryland *     470,187     488,116
# 19              Arizona *     458,950     479,759
# 20              Indiana *     455,750     473,353
# 21            Minnesota *     446,500     464,987
# 22            Wisconsin *     401,792     417,301
# 23             Missouri *     389,931     406,936
# 24          Connecticut *     321,845     333,102
# 25               Oregon *     299,125     316,593
# 26       South Carolina *     295,880     308,927
# 27            Louisiana *     281,429     289,945
# 28              Alabama *     277,817     289,038
# 29             Kentucky *     260,304     271,994
# 30                 Utah *     248,176     259,291
# 31             Oklahoma *     240,534     243,350
# 32                 Iowa *     231,108     241,248
# 33               Nevada *     215,918     228,930
# 34               Kansas *     210,670     220,402
# 35             Arkansas *     165,221     171,152
# 36             Nebraska *     161,702     170,145
# 37  District of Columbia*     162,314     168,559
# 38          Mississippi *     138,740     143,796
# 39           New Mexico *     122,115     124,480
# 40                Idaho *     109,546     114,923
# 41        New Hampshire *     105,414     109,985
# 42               Hawaii *      98,219     103,262
# 43        West Virginia *      95,588      96,012
# 44             Delaware *      87,525      91,581
# 45                Maine *      84,497      88,258
# 46         North Dakota *      73,267      73,866
# 47         Rhode Island *      71,402      74,094
# 48         South Dakota *      67,571      70,316
# 49              Montana *      65,015      67,785
# 50               Alaska *      63,618      63,750
# 51              Wyoming *      47,433      47,420
# 52              Vermont *      40,617      42,239
# 53        United States *  25,462,722  26,529,774

# %%
# check the detail of "state" column before cleaning
gdp['state'].tolist()
# Out:
# ['2022',
#  nan,
#  'California\u202f*',
#  'Texas\u202f*',
#  'New York\u202f*',
#  'Florida\u202f*',
#  'Illinois\u202f*',
#  'Pennsylvania\u202f*',
#  'Ohio\u202f*',
#  'Georgia\u202f*',
#  'New Jersey\u202f*',
#  'North Carolina\u202f*',
#  'Washington\u202f*',
#  'Massachusetts\u202f*',
#  'Virginia\u202f*',
#  'Michigan\u202f*',
#  'Colorado\u202f*',
#  'Tennessee\u202f*',
#  'Maryland\u202f*',
#  'Arizona\u202f*',
#  'Indiana\u202f*',
#  'Minnesota\u202f*',
#  'Wisconsin\u202f*',
#  'Missouri\u202f*',
#  'Connecticut\u202f*',
#  'Oregon\u202f*',
#  'South Carolina\u202f*',
#  'Louisiana\u202f*',
#  'Alabama\u202f*',
#  'Kentucky\u202f*',
#  'Utah\u202f*',
#  'Oklahoma\u202f*',
#  'Iowa\u202f*',
#  'Nevada\u202f*',
#  'Kansas\u202f*',
#  'Arkansas\u202f*',
#  'Nebraska\u202f*',
#  'District of Columbia*',
#  'Mississippi\u202f*',
#  'New Mexico\u202f*',
#  'Idaho\u202f*',
#  'New Hampshire\u202f*',
#  'Hawaii\u202f*',
#  'West Virginia\u202f*',
#  'Delaware\u202f*',
#  'Maine\u202f*',
#  'North Dakota\u202f*',
#  'Rhode Island\u202f*',
#  'South Dakota\u202f*',
#  'Montana\u202f*',
#  'Alaska\u202f*',
#  'Wyoming\u202f*',
#  'Vermont\u202f*',
#  'United States\u202f*']

# %%
# drop irrelevant rows
gdp.drop([0,1,53],inplace=True)
gdp.reset_index(drop=True, inplace=True)

# %%
# clean state column
gdp['state'] = gdp['state'].apply(lambda x: re.sub(r'[\u202f*]', '', x))

# %%
# clean gdp columns, change data type from str to int
gdp['gdp_2022'] = gdp['gdp_2022'].apply(lambda x: x.replace(',', '').strip()).astype(int)
gdp['gdp_2023'] = gdp['gdp_2023'].apply(lambda x: x.replace(',', '').strip()).astype(int)

# %%
# after cleaning
gdp['state'].tolist()
# Out:
# ['California',
#  'Texas',
#  'New York',
#  'Florida',
#  'Illinois',
#  'Pennsylvania',
#  'Ohio',
#  'Georgia',
#  'New Jersey',
#  'North Carolina',
#  'Washington',
#  'Massachusetts',
#  'Virginia',
#  'Michigan',
#  'Colorado',
#  'Tennessee',
#  'Maryland',
#  'Arizona',
#  'Indiana',
#  'Minnesota',
#  'Wisconsin',
#  'Missouri',
#  'Connecticut',
#  'Oregon',
#  'South Carolina',
#  'Louisiana',
#  'Alabama',
#  'Kentucky',
#  'Utah',
#  'Oklahoma',
#  'Iowa',
#  'Nevada',
#  'Kansas',
#  'Arkansas',
#  'Nebraska',
#  'District of Columbia',
#  'Mississippi',
#  'New Mexico',
#  'Idaho',
#  'New Hampshire',
#  'Hawaii',
#  'West Virginia',
#  'Delaware',
#  'Maine',
#  'North Dakota',
#  'Rhode Island',
#  'South Dakota',
#  'Montana',
#  'Alaska',
#  'Wyoming',
#  'Vermont']

# %%
# add one more column as "change_percentage" to calculate the percentage change of gdp from 2022 to 2023
gdp['change_percentage'] = (gdp['gdp_2023'] - gdp['gdp_2022'])/gdp['gdp_2022']

# %%
gdp
# Out:
#                    state  gdp_2022  gdp_2023  change_percentage
# 0             California   3598103   3755487           0.043741
# 1                  Texas   2355960   2436346           0.034120
# 2               New York   2053180   2135672           0.040178
# 3                Florida   1389070   1468015           0.056833
# 4               Illinois   1033310   1071552           0.037009
# 5           Pennsylvania    923089    961946           0.042095
# 6                   Ohio    822670    852903           0.036750
# 7                Georgia    755698    792151           0.048238
# 8             New Jersey    745422    776923           0.042259
# 9         North Carolina    730072    762866           0.044919
# 10            Washington    725514    761415           0.049484
# 11         Massachusetts    688392    721876           0.048641
# 12              Virginia    649393    676734           0.042102
# 13              Michigan    620696    645293           0.039628
# 14              Colorado    484372    502026           0.036447
# 15             Tennessee    475755    502664           0.056561
# 16              Maryland    470187    488116           0.038132
# 17               Arizona    458950    479759           0.045340
# 18               Indiana    455750    473353           0.038624
# 19             Minnesota    446500    464987           0.041404
# 20             Wisconsin    401792    417301           0.038600
# 21              Missouri    389931    406936           0.043610
# 22           Connecticut    321845    333102           0.034976
# 23                Oregon    299125    316593           0.058397
# 24        South Carolina    295880    308927           0.044096
# 25             Louisiana    281429    289945           0.030260
# 26               Alabama    277817    289038           0.040390
# 27              Kentucky    260304    271994           0.044909
# 28                  Utah    248176    259291           0.044787
# 29              Oklahoma    240534    243350           0.011707
# 30                  Iowa    231108    241248           0.043876
# 31                Nevada    215918    228930           0.060264
# 32                Kansas    210670    220402           0.046195
# 33              Arkansas    165221    171152           0.035897
# 34              Nebraska    161702    170145           0.052213
# 35  District of Columbia    162314    168559           0.038475
# 36           Mississippi    138740    143796           0.036442
# 37            New Mexico    122115    124480           0.019367
# 38                 Idaho    109546    114923           0.049084
# 39         New Hampshire    105414    109985           0.043362
# 40                Hawaii     98219    103262           0.051344
# 41         West Virginia     95588     96012           0.004436
# 42              Delaware     87525     91581           0.046341
# 43                 Maine     84497     88258           0.044510
# 44          North Dakota     73267     73866           0.008176
# 45          Rhode Island     71402     74094           0.037702
# 46          South Dakota     67571     70316           0.040624
# 47               Montana     65015     67785           0.042606
# 48                Alaska     63618     63750           0.002075
# 49               Wyoming     47433     47420          -0.000274
# 50               Vermont     40617     42239           0.039934

# %%
# already stored under "processed" folder 
#gdp.to_excel('data/processed/gdp_clean.xlsx', index=False)

# %% [markdown]
# # 3. Data Cleaning for State Name Dataset

# %%
state_name.head(5)
# Out:
#                       state state_abbreviation
# 0  United States of America           USUSA840
# 1                   Alabama              US-AL
# 2                    Alaska              US-AK
# 3                   Arizona              US-AZ
# 4                  Arkansas              US-AR

# %%
# have some non-match columns
print(len(state_name))
print(len(gdp))
# Out:
# 78
# 51

# %%
state_name_gdp = pd.merge(state_name,gdp,on='state')

state_name_gdp['state_abbreviation'].fillna('Unknown', inplace=True)
state_name_gdp['state_abbreviation'] = state_name_gdp['state_abbreviation'].apply(lambda x: x.replace('US-',''))

# %%
state_name_gdp.head(5)
# Out:
#         state state_abbreviation  gdp_2022  gdp_2023  change_percentage
# 0     Alabama                 AL    277817    289038           0.040390
# 1      Alaska                 AK     63618     63750           0.002075
# 2     Arizona                 AZ    458950    479759           0.045340
# 3    Arkansas                 AR    165221    171152           0.035897
# 4  California                 CA   3598103   3755487           0.043741

# %%
# already stored under "processed" folder
#state_name_gdp.to_excel('data/processed/state_name_gdp_clean.xlsx', index=False)

# %% [markdown]
# # 4. Data Cleaning for Yahoo Finance Dataset

# %%
fin.rename(columns={'symbol': 'Symbol'}, inplace=True)

# %%
fin
# Out:
#     Symbol   market_value  latest_revenue  stock_volatility
# 0        A    33349068800      6848000000          0.016883
# 1      AAL     8103907840     48971000000          0.023060
# 2      AAP     3153115392     11154722000          0.031097
# 3     AAPL  2977583333376    383285000000          0.014296
# 4     ABBV   244191821824     58054000000          0.012325
# ..     ...            ...             ...               ...
# 498    YUM    35913060352      6842000000          0.010160
# 499    ZBH    23510362112      6939900000          0.013304
# 500   ZBRA    11326845952      5781000000          0.025469
# 501   ZION     5300770816      3152000000          0.039206
# 502    ZTS    80831610880      8080000000          0.016121
#
# [503 rows x 4 columns]

# %%
# check null value
fin.isnull().sum()
# Out:
# Symbol              0
# market_value        0
# latest_revenue      0
# stock_volatility    2
# dtype: int64

# %%
# delete BF.B, cuz this company doesn't have ESG scores, also deleted in the previous step
# keep company ABC
fin[fin['stock_volatility'].isnull()]
# Out:
#    Symbol  market_value  latest_revenue  stock_volatility
# 5     ABC             0               0               NaN
# 61   BF.B             0               0               NaN

# %%
esg[esg['Symbol']=='ABC']
# Out:
#   Symbol                    Name  \
# 5    ABC  Amerisourcebergen Corp
#
#                                              Address      Sector  \
# 5  1 West First Avenue\nConshohocken, PA 19428-18...  Healthcare
#
#                Industry  Full Time Employees  \
# 5  Medical Distribution                46000
#
#                                          Description  Total ESG Risk score  \
# 5  AmerisourceBergen Corporation sources and dist...                  12.0
#
#    Environment Risk Score  Governance Risk Score  Social Risk Score  \
# 5                     1.3                    5.2                5.6
#
#   Controversy Level  Controversy Score ESG Risk Percentile ESG Risk Level
# 5       Significant                3.0      5th percentile            Low

# %%
fin.drop([61],inplace=True)
fin.reset_index(drop=True, inplace=True)

# %%
fin
# Out:
#     Symbol   market_value  latest_revenue  stock_volatility
# 0        A    33349068800      6848000000          0.016883
# 1      AAL     8103907840     48971000000          0.023060
# 2      AAP     3153115392     11154722000          0.031097
# 3     AAPL  2977583333376    383285000000          0.014296
# 4     ABBV   244191821824     58054000000          0.012325
# ..     ...            ...             ...               ...
# 497    YUM    35913060352      6842000000          0.010160
# 498    ZBH    23510362112      6939900000          0.013304
# 499   ZBRA    11326845952      5781000000          0.025469
# 500   ZION     5300770816      3152000000          0.039206
# 501    ZTS    80831610880      8080000000          0.016121
#
# [502 rows x 4 columns]

# %%
# already stored under "processed" folder
#fin.to_excel('data/processed/fin_clean.xlsx', index=False)
